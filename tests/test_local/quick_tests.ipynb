# %%
import simanager as sim

# %%
study = sim.SimulationStudy.load_folder("./")

# %%
study.initialize_folders()
# Out:
# Total number of parameter combinations: 24
# [1, 2, 3]
# 1
# 1.0
# [4, 5, 6]
# 1
# 1.0
# [1, 2, 3]
# 2
# 1.0
# [4, 5, 6]
# 2
# 1.0
# [1, 2, 3]
# 3
# 1.0
# [4, 5, 6]
# 3
# 1.0
# [1, 2, 3]
# 1
# 1.3333333333333333
# [4, 5, 6]
# 1
# 1.3333333333333333
# [1, 2, 3]
# 2
# 1.3333333333333333
# [4, 5, 6]
# 2
# 1.3333333333333333
# [1, 2, 3]
# 3
# 1.3333333333333333
# [4, 5, 6]
# 3
# 1.3333333333333333
# [1, 2, 3]
# 1
# 1.6666666666666665
# [4, 5, 6]
# 1
# 1.6666666666666665
# [1, 2, 3]
# 2
# 1.6666666666666665
# [4, 5, 6]
# 2
# 1.6666666666666665
# [1, 2, 3]
# 3
# 1.6666666666666665
# [4, 5, 6]
# 3
# 1.6666666666666665
# [1, 2, 3]
# 1
# 2.0
# [4, 5, 6]
# 1
# 2.0
# [1, 2, 3]
# 2
# 2.0
# [4, 5, 6]
# 2
# 2.0
# [1, 2, 3]
# 3
# 2.0
# [4, 5, 6]
# 3
# 2.0

# %%
study.print_sim_status()
# Out:
# ------------------------------------------------------------
# Simulation status:
# ------------------------------------------------------------
# Number of simulations not started: 24
# Number of simulations running: 0
# Number of simulations finished: 0
# Number of simulations interrupted: 0
# Number of simulations with error: 0
# ------------------------------------------------------------
# Simulations not started:
# ------------------------------------------------------------
# case_nlist_0_mxatt_1d0_tout_1d0
# case_nlist_1_mxatt_1d0_tout_1d0
# case_nlist_0_mxatt_2d0_tout_1d0
# case_nlist_1_mxatt_2d0_tout_1d0
# case_nlist_0_mxatt_3d0_tout_1d0
# case_nlist_1_mxatt_3d0_tout_1d0
# case_nlist_0_mxatt_1d0_tout_1d33
# case_nlist_1_mxatt_1d0_tout_1d33
# case_nlist_0_mxatt_2d0_tout_1d33
# case_nlist_1_mxatt_2d0_tout_1d33
# case_nlist_0_mxatt_3d0_tout_1d33
# case_nlist_1_mxatt_3d0_tout_1d33
# case_nlist_0_mxatt_1d0_tout_1d67
# case_nlist_1_mxatt_1d0_tout_1d67
# case_nlist_0_mxatt_2d0_tout_1d67
# case_nlist_1_mxatt_2d0_tout_1d67
# case_nlist_0_mxatt_3d0_tout_1d67
# case_nlist_1_mxatt_3d0_tout_1d67
# case_nlist_0_mxatt_1d0_tout_2d0
# case_nlist_1_mxatt_1d0_tout_2d0
# case_nlist_0_mxatt_2d0_tout_2d0
# case_nlist_1_mxatt_2d0_tout_2d0
# case_nlist_0_mxatt_3d0_tout_2d0
# case_nlist_1_mxatt_3d0_tout_2d0
# ------------------------------------------------------------
# Simulations running:
# ------------------------------------------------------------
# ------------------------------------------------------------
# Simulations finished:
# ------------------------------------------------------------
# ------------------------------------------------------------
# Simulations interrupted:
# ------------------------------------------------------------
# ------------------------------------------------------------
# Simulations with error:
# ------------------------------------------------------------
# ------------------------------------------------------------

# %%
sim.job_run_local(study, gpu_available_list=[0,1])
# Out:
# Shared simulation status: ['case_nlist_0_mxatt_1d0_tout_1d0', 'case_nlist_1_mxatt_1d0_tout_1d0', 'case_nlist_0_mxatt_2d0_tout_1d0', 'case_nlist_1_mxatt_2d0_tout_1d0', 'case_nlist_0_mxatt_3d0_tout_1d0', 'case_nlist_1_mxatt_3d0_tout_1d0', 'case_nlist_0_mxatt_1d0_tout_1d33', 'case_nlist_1_mxatt_1d0_tout_1d33', 'case_nlist_0_mxatt_2d0_tout_1d33', 'case_nlist_1_mxatt_2d0_tout_1d33', 'case_nlist_0_mxatt_3d0_tout_1d33', 'case_nlist_1_mxatt_3d0_tout_1d33', 'case_nlist_0_mxatt_1d0_tout_1d67', 'case_nlist_1_mxatt_1d0_tout_1d67', 'case_nlist_0_mxatt_2d0_tout_1d67', 'case_nlist_1_mxatt_2d0_tout_1d67', 'case_nlist_0_mxatt_3d0_tout_1d67', 'case_nlist_1_mxatt_3d0_tout_1d67', 'case_nlist_0_mxatt_1d0_tout_2d0', 'case_nlist_1_mxatt_1d0_tout_2d0', 'case_nlist_0_mxatt_2d0_tout_2d0', 'case_nlist_1_mxatt_2d0_tout_2d0', 'case_nlist_0_mxatt_3d0_tout_2d0', 'case_nlist_1_mxatt_3d0_tout_2d0']
# Running simulations...
# Started running at 2023-10-06 14:01:50.486952...
# Created a pool with 12 jobs...
# Running simulation in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_0_mxatt_1d0_tout_1d0 on GPU 0...
# Running simulation in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_1_mxatt_1d0_tout_1d0 on GPU 1...
# Created a pool with 12 jobs...
# Finished running simulations...
# Finished running at 2023-10-06 14:01:50.509191...
# Finished running simulation in folder case_nlist_0_mxatt_1d0_tout_1d0 on GPU 0...
# Finished running simulation in folder case_nlist_1_mxatt_1d0_tout_1d0 on GPU 1...
# Running simulation in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_0_mxatt_2d0_tout_1d0 on GPU 0...
# Running simulation in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_1_mxatt_2d0_tout_1d0 on GPU 1...
# Finished running simulation in folder case_nlist_0_mxatt_2d0_tout_1d0 on GPU 0...
# Running simulation in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_0_mxatt_3d0_tout_1d0 on GPU 0...
# Finished running simulation in folder case_nlist_1_mxatt_2d0_tout_1d0 on GPU 1...
# Running simulation in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_1_mxatt_3d0_tout_1d0 on GPU 1...
# Finished running simulation in folder case_nlist_1_mxatt_3d0_tout_1d0 on GPU 1...
# Finished running simulation in folder case_nlist_0_mxatt_3d0_tout_1d0 on GPU 0...
# Running simulation in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_1_mxatt_1d0_tout_1d33 on GPU 1...
# Running simulation in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_0_mxatt_1d0_tout_1d33 on GPU 0...
# Finished running simulation in folder case_nlist_1_mxatt_1d0_tout_1d33 on GPU 1...
# Running simulation in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_1_mxatt_2d0_tout_1d33 on GPU 1...
# Finished running simulation in folder case_nlist_0_mxatt_1d0_tout_1d33 on GPU 0...
# Running simulation in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_0_mxatt_2d0_tout_1d33 on GPU 0...
# Finished running simulation in folder case_nlist_1_mxatt_2d0_tout_1d33 on GPU 1...
# Running simulation in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_1_mxatt_3d0_tout_1d33 on GPU 1...
# Finished running simulation in folder case_nlist_0_mxatt_2d0_tout_1d33 on GPU 0...
# Running simulation in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_0_mxatt_3d0_tout_1d33 on GPU 0...
# Finished running simulation in folder case_nlist_1_mxatt_3d0_tout_1d33 on GPU 1...
# Running simulation in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_1_mxatt_1d0_tout_1d67 on GPU 1...
# Finished running simulation in folder case_nlist_0_mxatt_3d0_tout_1d33 on GPU 0...
# Running simulation in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_0_mxatt_1d0_tout_1d67 on GPU 0...
# Finished running simulation in folder case_nlist_1_mxatt_1d0_tout_1d67 on GPU 1...
# Running simulation in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_1_mxatt_2d0_tout_1d67 on GPU 1...
# Finished running simulation in folder case_nlist_0_mxatt_1d0_tout_1d67 on GPU 0...
# Running simulation in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_0_mxatt_2d0_tout_1d67 on GPU 0...
# Finished running simulation in folder case_nlist_1_mxatt_2d0_tout_1d67 on GPU 1...
# Running simulation in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_1_mxatt_3d0_tout_1d67 on GPU 1...
# Finished running simulation in folder case_nlist_0_mxatt_2d0_tout_1d67 on GPU 0...
# Running simulation in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_0_mxatt_3d0_tout_1d67 on GPU 0...
# Finished running simulation in folder case_nlist_1_mxatt_3d0_tout_1d67 on GPU 1...
# Finished running simulation in folder case_nlist_0_mxatt_3d0_tout_1d67 on GPU 0...
# Running simulation in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_1_mxatt_1d0_tout_2d0 on GPU 1...
# Running simulation in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_0_mxatt_1d0_tout_2d0 on GPU 0...
# Finished running simulation in folder case_nlist_1_mxatt_1d0_tout_2d0 on GPU 1...
# Running simulation in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_1_mxatt_2d0_tout_2d0 on GPU 1...
# Finished running simulation in folder case_nlist_0_mxatt_1d0_tout_2d0 on GPU 0...
# Running simulation in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_0_mxatt_2d0_tout_2d0 on GPU 0...
# Finished running simulation in folder case_nlist_0_mxatt_2d0_tout_2d0 on GPU 0...
# Finished running simulation in folder case_nlist_1_mxatt_2d0_tout_2d0 on GPU 1...
# Running simulation in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_0_mxatt_3d0_tout_2d0 on GPU 0...
# Running simulation in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_1_mxatt_3d0_tout_2d0 on GPU 1...
# Finished running simulation in folder case_nlist_0_mxatt_3d0_tout_2d0 on GPU 0...
# Finished running simulation in folder case_nlist_1_mxatt_3d0_tout_2d0 on GPU 1...
# Total running time: 0:00:17.572188...
# Updating simulation info...

# %%
study.print_sim_status()
# Out:
# ------------------------------------------------------------
# Simulation status:
# ------------------------------------------------------------
# Number of simulations not started: 0
# Number of simulations running: 0
# Number of simulations finished: 24
# Number of simulations interrupted: 0
# Number of simulations with error: 0
# ------------------------------------------------------------
# Simulations not started:
# ------------------------------------------------------------
# ------------------------------------------------------------
# Simulations running:
# ------------------------------------------------------------
# ------------------------------------------------------------
# Simulations finished:
# ------------------------------------------------------------
# case_nlist_0_mxatt_1d0_tout_1d0
# case_nlist_1_mxatt_1d0_tout_1d0
# case_nlist_0_mxatt_2d0_tout_1d0
# case_nlist_1_mxatt_2d0_tout_1d0
# case_nlist_1_mxatt_3d0_tout_1d0
# case_nlist_0_mxatt_3d0_tout_1d0
# case_nlist_1_mxatt_1d0_tout_1d33
# case_nlist_0_mxatt_1d0_tout_1d33
# case_nlist_1_mxatt_2d0_tout_1d33
# case_nlist_0_mxatt_2d0_tout_1d33
# case_nlist_1_mxatt_3d0_tout_1d33
# case_nlist_0_mxatt_3d0_tout_1d33
# case_nlist_1_mxatt_1d0_tout_1d67
# case_nlist_0_mxatt_1d0_tout_1d67
# case_nlist_1_mxatt_2d0_tout_1d67
# case_nlist_0_mxatt_2d0_tout_1d67
# case_nlist_1_mxatt_3d0_tout_1d67
# case_nlist_0_mxatt_3d0_tout_1d67
# case_nlist_1_mxatt_1d0_tout_2d0
# case_nlist_0_mxatt_1d0_tout_2d0
# case_nlist_0_mxatt_2d0_tout_2d0
# case_nlist_1_mxatt_2d0_tout_2d0
# case_nlist_0_mxatt_3d0_tout_2d0
# case_nlist_1_mxatt_3d0_tout_2d0
# ------------------------------------------------------------
# Simulations interrupted:
# ------------------------------------------------------------
# ------------------------------------------------------------
# Simulations with error:
# ------------------------------------------------------------
# ------------------------------------------------------------

# %%
study.reset_simulations(reset_all=True, restore_original=True, clear_out_folder=True, clear_err_folder=True, clear_log_folder=True)
# Out:
# Resetting case_nlist_0_mxatt_1d0_tout_1d0
# Removed case_nlist_0_mxatt_1d0_tout_1d0 from sim_finished
# Resetting case_nlist_1_mxatt_1d0_tout_1d0
# Removed case_nlist_1_mxatt_1d0_tout_1d0 from sim_finished
# Resetting case_nlist_0_mxatt_2d0_tout_1d0
# Removed case_nlist_0_mxatt_2d0_tout_1d0 from sim_finished
# Resetting case_nlist_1_mxatt_2d0_tout_1d0
# Removed case_nlist_1_mxatt_2d0_tout_1d0 from sim_finished
# Resetting case_nlist_1_mxatt_3d0_tout_1d0
# Removed case_nlist_1_mxatt_3d0_tout_1d0 from sim_finished
# Resetting case_nlist_0_mxatt_3d0_tout_1d0
# Removed case_nlist_0_mxatt_3d0_tout_1d0 from sim_finished
# Resetting case_nlist_1_mxatt_1d0_tout_1d33
# Removed case_nlist_1_mxatt_1d0_tout_1d33 from sim_finished
# Resetting case_nlist_0_mxatt_1d0_tout_1d33
# Removed case_nlist_0_mxatt_1d0_tout_1d33 from sim_finished
# Resetting case_nlist_1_mxatt_2d0_tout_1d33
# Removed case_nlist_1_mxatt_2d0_tout_1d33 from sim_finished
# Resetting case_nlist_0_mxatt_2d0_tout_1d33
# Removed case_nlist_0_mxatt_2d0_tout_1d33 from sim_finished
# Resetting case_nlist_1_mxatt_3d0_tout_1d33
# Removed case_nlist_1_mxatt_3d0_tout_1d33 from sim_finished
# Resetting case_nlist_0_mxatt_3d0_tout_1d33
# Removed case_nlist_0_mxatt_3d0_tout_1d33 from sim_finished
# Resetting case_nlist_1_mxatt_1d0_tout_1d67
# Removed case_nlist_1_mxatt_1d0_tout_1d67 from sim_finished
# Resetting case_nlist_0_mxatt_1d0_tout_1d67
# Removed case_nlist_0_mxatt_1d0_tout_1d67 from sim_finished
# Resetting case_nlist_1_mxatt_2d0_tout_1d67
# Removed case_nlist_1_mxatt_2d0_tout_1d67 from sim_finished
# Resetting case_nlist_0_mxatt_2d0_tout_1d67
# Removed case_nlist_0_mxatt_2d0_tout_1d67 from sim_finished
# Resetting case_nlist_1_mxatt_3d0_tout_1d67
# Removed case_nlist_1_mxatt_3d0_tout_1d67 from sim_finished
# Resetting case_nlist_0_mxatt_3d0_tout_1d67
# Removed case_nlist_0_mxatt_3d0_tout_1d67 from sim_finished
# Resetting case_nlist_1_mxatt_1d0_tout_2d0
# Removed case_nlist_1_mxatt_1d0_tout_2d0 from sim_finished
# Resetting case_nlist_0_mxatt_1d0_tout_2d0
# Removed case_nlist_0_mxatt_1d0_tout_2d0 from sim_finished
# Resetting case_nlist_0_mxatt_2d0_tout_2d0
# Removed case_nlist_0_mxatt_2d0_tout_2d0 from sim_finished
# Resetting case_nlist_1_mxatt_2d0_tout_2d0
# Removed case_nlist_1_mxatt_2d0_tout_2d0 from sim_finished
# Resetting case_nlist_0_mxatt_3d0_tout_2d0
# Removed case_nlist_0_mxatt_3d0_tout_2d0 from sim_finished
# Resetting case_nlist_1_mxatt_3d0_tout_2d0
# Removed case_nlist_1_mxatt_3d0_tout_2d0 from sim_finished

# %%
sim.job_run_local(study)
# Out:
# Running simulation 0 in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_0_mxatt_1d0_tout_1d0...
# Running simulation 1 in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_1_mxatt_1d0_tout_1d0...
# Running simulation 2 in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_0_mxatt_2d0_tout_1d0...
# Running simulation 3 in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_1_mxatt_2d0_tout_1d0...
# Running simulation 4 in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_1_mxatt_3d0_tout_1d0...
# Running simulation 5 in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_0_mxatt_3d0_tout_1d0...
# Running simulation 6 in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_1_mxatt_1d0_tout_1d33...
# Running simulation 7 in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_0_mxatt_1d0_tout_1d33...
# Running simulation 8 in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_1_mxatt_2d0_tout_1d33...
# Running simulation 9 in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_0_mxatt_2d0_tout_1d33...
# Running simulation 10 in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_1_mxatt_3d0_tout_1d33...
# Running simulation 11 in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_0_mxatt_3d0_tout_1d33...
# Running simulation 12 in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_1_mxatt_1d0_tout_1d67...
# Running simulation 13 in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_0_mxatt_1d0_tout_1d67...
# Running simulation 14 in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_1_mxatt_2d0_tout_1d67...
# Running simulation 15 in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_0_mxatt_2d0_tout_1d67...
# Running simulation 16 in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_1_mxatt_3d0_tout_1d67...
# Running simulation 17 in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_0_mxatt_3d0_tout_1d67...
# Running simulation 18 in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_1_mxatt_1d0_tout_2d0...
# Running simulation 19 in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_0_mxatt_1d0_tout_2d0...
# Running simulation 20 in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_0_mxatt_2d0_tout_2d0...
# Running simulation 21 in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_1_mxatt_2d0_tout_2d0...
# Running simulation 22 in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_0_mxatt_3d0_tout_2d0...
# Running simulation 23 in folder /home/camontan/cernbox/work/code/generic_study/tests/test_local/test_local/scan/case_nlist_1_mxatt_3d0_tout_2d0...
# Running simulations...
# Started running at 2023-10-06 14:02:37.708979...
# Finished running simulations...
# Finished running at 2023-10-06 14:02:40.508657...
# Total running time: 0:00:02.799678...

# %%
study.print_sim_status()
# Out:
# ------------------------------------------------------------
# Simulation status:
# ------------------------------------------------------------
# Number of simulations not started: 0
# Number of simulations running: 0
# Number of simulations finished: 24
# Number of simulations interrupted: 0
# Number of simulations with error: 0
# ------------------------------------------------------------
# Simulations not started:
# ------------------------------------------------------------
# ------------------------------------------------------------
# Simulations running:
# ------------------------------------------------------------
# ------------------------------------------------------------
# Simulations finished:
# ------------------------------------------------------------
# case_nlist_0_mxatt_1d0_tout_1d0
# case_nlist_1_mxatt_1d0_tout_1d0
# case_nlist_0_mxatt_2d0_tout_1d0
# case_nlist_1_mxatt_2d0_tout_1d0
# case_nlist_1_mxatt_3d0_tout_1d0
# case_nlist_0_mxatt_3d0_tout_1d0
# case_nlist_1_mxatt_1d0_tout_1d33
# case_nlist_0_mxatt_1d0_tout_1d33
# case_nlist_1_mxatt_2d0_tout_1d33
# case_nlist_0_mxatt_2d0_tout_1d33
# case_nlist_1_mxatt_3d0_tout_1d33
# case_nlist_0_mxatt_3d0_tout_1d33
# case_nlist_1_mxatt_1d0_tout_1d67
# case_nlist_0_mxatt_1d0_tout_1d67
# case_nlist_1_mxatt_2d0_tout_1d67
# case_nlist_0_mxatt_2d0_tout_1d67
# case_nlist_1_mxatt_3d0_tout_1d67
# case_nlist_0_mxatt_3d0_tout_1d67
# case_nlist_1_mxatt_1d0_tout_2d0
# case_nlist_0_mxatt_1d0_tout_2d0
# case_nlist_0_mxatt_2d0_tout_2d0
# case_nlist_1_mxatt_2d0_tout_2d0
# case_nlist_0_mxatt_3d0_tout_2d0
# case_nlist_1_mxatt_3d0_tout_2d0
# ------------------------------------------------------------
# Simulations interrupted:
# ------------------------------------------------------------
# ------------------------------------------------------------
# Simulations with error:
# ------------------------------------------------------------
# ------------------------------------------------------------

# %%
study.reset_simulations(reset_all=True, restore_original=True, clear_out_folder=True, clear_err_folder=True, clear_log_folder=True)
# Out:
# Resetting case_nlist_0_mxatt_1d0_tout_1d0
# Removed case_nlist_0_mxatt_1d0_tout_1d0 from sim_finished
# Resetting case_nlist_1_mxatt_1d0_tout_1d0
# Removed case_nlist_1_mxatt_1d0_tout_1d0 from sim_finished
# Resetting case_nlist_0_mxatt_2d0_tout_1d0
# Removed case_nlist_0_mxatt_2d0_tout_1d0 from sim_finished
# Resetting case_nlist_1_mxatt_2d0_tout_1d0
# Removed case_nlist_1_mxatt_2d0_tout_1d0 from sim_finished
# Resetting case_nlist_1_mxatt_3d0_tout_1d0
# Removed case_nlist_1_mxatt_3d0_tout_1d0 from sim_finished
# Resetting case_nlist_0_mxatt_3d0_tout_1d0
# Removed case_nlist_0_mxatt_3d0_tout_1d0 from sim_finished
# Resetting case_nlist_1_mxatt_1d0_tout_1d33
# Removed case_nlist_1_mxatt_1d0_tout_1d33 from sim_finished
# Resetting case_nlist_0_mxatt_1d0_tout_1d33
# Removed case_nlist_0_mxatt_1d0_tout_1d33 from sim_finished
# Resetting case_nlist_1_mxatt_2d0_tout_1d33
# Removed case_nlist_1_mxatt_2d0_tout_1d33 from sim_finished
# Resetting case_nlist_0_mxatt_2d0_tout_1d33
# Removed case_nlist_0_mxatt_2d0_tout_1d33 from sim_finished
# Resetting case_nlist_1_mxatt_3d0_tout_1d33
# Removed case_nlist_1_mxatt_3d0_tout_1d33 from sim_finished
# Resetting case_nlist_0_mxatt_3d0_tout_1d33
# Removed case_nlist_0_mxatt_3d0_tout_1d33 from sim_finished
# Resetting case_nlist_1_mxatt_1d0_tout_1d67
# Removed case_nlist_1_mxatt_1d0_tout_1d67 from sim_finished
# Resetting case_nlist_0_mxatt_1d0_tout_1d67
# Removed case_nlist_0_mxatt_1d0_tout_1d67 from sim_finished
# Resetting case_nlist_1_mxatt_2d0_tout_1d67
# Removed case_nlist_1_mxatt_2d0_tout_1d67 from sim_finished
# Resetting case_nlist_0_mxatt_2d0_tout_1d67
# Removed case_nlist_0_mxatt_2d0_tout_1d67 from sim_finished
# Resetting case_nlist_1_mxatt_3d0_tout_1d67
# Removed case_nlist_1_mxatt_3d0_tout_1d67 from sim_finished
# Resetting case_nlist_0_mxatt_3d0_tout_1d67
# Removed case_nlist_0_mxatt_3d0_tout_1d67 from sim_finished
# Resetting case_nlist_1_mxatt_1d0_tout_2d0
# Removed case_nlist_1_mxatt_1d0_tout_2d0 from sim_finished
# Resetting case_nlist_0_mxatt_1d0_tout_2d0
# Removed case_nlist_0_mxatt_1d0_tout_2d0 from sim_finished
# Resetting case_nlist_0_mxatt_2d0_tout_2d0
# Removed case_nlist_0_mxatt_2d0_tout_2d0 from sim_finished
# Resetting case_nlist_1_mxatt_2d0_tout_2d0
# Removed case_nlist_1_mxatt_2d0_tout_2d0 from sim_finished
# Resetting case_nlist_0_mxatt_3d0_tout_2d0
# Removed case_nlist_0_mxatt_3d0_tout_2d0 from sim_finished
# Resetting case_nlist_1_mxatt_3d0_tout_2d0
# Removed case_nlist_1_mxatt_3d0_tout_2d0 from sim_finished
